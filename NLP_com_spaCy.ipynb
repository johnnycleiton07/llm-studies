# %% [markdown]
# <a href="https://colab.research.google.com/github/johnnycleiton07/llm-studies/blob/main/NLP_com_spaCy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #spaCy
#
# A biblioteca spaCy é uma poderosa ferramenta de processamento de linguagem natural (NLP) desenvolvida em Python, amplamente utilizada para realizar uma variedade de tarefas relacionadas ao processamento e análise de textos.
#
# spaCy oferece diversas funcionalidades, incluindo:
#
# * Tokenização: Divide o texto em unidades menores, como palavras, pontuações e números.
# * Part-of-Speech Tagging (POS): Atribui rótulos às palavras, indicando sua função gramatical (substantivo, verbo, adjetivo, etc.).
# * Named Entity Recognition (NER): Identifica e classifica entidades nomeadas, como pessoas, organizações, locais e datas.
# * Dependência Sintática: Analisa as relações gramaticais entre as palavras no texto.
# * Vetorização de Palavras: Representa palavras como vetores densos, capturando semelhanças semânticas entre elas.
# * Reconhecimento de Frases e Entidades: Detecta padrões específicos, como frases de datas ou valores monetários.

# %% [markdown]
# ##Configurações Iniciais

# %%
# !pip install -U spacy==3.2.0
# Out:
# Requirement already satisfied: spacy==3.2.0 in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (2.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (4.66.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.2.0) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.2.0) (1.2.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy==3.2.0) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy==3.2.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy==3.2.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.2.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.2.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.2.0) (2024.6.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.5.0,>=0.3.0->spacy==3.2.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy==3.2.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.2.0) (1.2.0)

# %%
#baixar modelo pré-treinado em português (lg é a versão large de 550MB)

# !python -m spacy download 'pt_core_news_lg'
# Out:
# 2024-07-10 12:42:41.827517: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-10 12:42:41.827633: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-10 12:42:41.986806: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-10 12:42:42.178798: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-10 12:42:44.348082: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.2.0/pt_core_news_lg-3.2.0-py3-none-any.whl#egg=pt_core_news_lg==3.2.0 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting pt-core-news-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.2.0/pt_core_news_lg-3.2.0-py3-none-any.whl (577.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.4/577.4 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.2.0) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (2.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (4.66.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (1.2.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (2024.6.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.3.0,>=3.2.0->pt-core-news-lg==3.2.0) (1.2.0)
# Installing collected packages: pt-core-news-lg
# Successfully installed pt-core-news-lg-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')

# %%
import spacy

# %%
#cria um objeto para usar o modelo pré-treinado

nlp = spacy.load('pt_core_news_lg')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:747: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:431.)
#   _C._set_default_tensor_type(t)

# %%
print(type(nlp))
# Out:
# <class 'spacy.lang.pt.Portuguese'>

# %%
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
documento = nlp("Um atleta de 15 anos que se junta ao Clube Oculto de sua escola para evitar o time de atletismo. Depois de encontrar e abrir uma caixa contendo um feitiço amaldiçoado semelhante a um dedo podre, sua escola é atacada por criaturas fantasmas conhecidas como Maldições. Para proteger seus amigos, ele consome o dedo podre e fica possuído por uma maldição conhecida como Ryoumen Sukuna.")
#documento = nlp("Alegações extraordinárias requerem evidências extraordinárias. Carl Sagan: 'https://carlsagan.com'")

# %%
len(documento.vocab)
# Out:
# 400

# %%
print(type(documento))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %% [markdown]
# ##Produção de Tokens
#
# Essa não é uma etapa opcional no pipeline, ela sempre será executada.

# %%
for token in documento:
  print (token.text)
# Out:
# Um
# atleta
# de
# 15
# anos
# que
# se
# junta
# ao
# Clube
# Oculto
# de
# sua
# escola
# para
# evitar
# o
# time
# de
# atletismo
# .
# Depois
# de
# encontrar
# e
# abrir
# uma
# caixa
# contendo
# um
# feitiço
# amaldiçoado
# semelhante
# a
# um
# dedo
# podre
# ,
# sua
# escola
# é
# atacada
# por
# criaturas
# fantasmas
# conhecidas
# como
# Maldições
# .
# Para
# proteger
# seus
# amigos
# ,
# ele
# consome
# o
# dedo
# podre
# e
# fica
# possuído
# por
# uma
# maldição
# conhecida
# como
# Ryoumen
# Sukuna
# .

# %%
print(documento[67])
# Out:
# Ryoumen

# %%
print(documento[67:69])
# Out:
# Ryoumen Sukuna

# %%
print(len(documento))
# Out:
# 70

# %%
print("Tokens: ", [token.text for token in documento])
print("Stop Word: ", [token.is_stop for token in documento])
print("Alfanumérico: ", [token.is_alpha for token in documento])
print("Maiúsculo: ", [token.is_upper for token in documento])
print("Pontuação: ", [token.is_punct for token in documento])
print("Número: ", [token.like_num for token in documento])
print("Sentença Inicial: ", [token.is_sent_start for token in documento])
# Out:
# Tokens:  ['Um', 'atleta', 'de', '15', 'anos', 'que', 'se', 'junta', 'ao', 'Clube', 'Oculto', 'de', 'sua', 'escola', 'para', 'evitar', 'o', 'time', 'de', 'atletismo', '.', 'Depois', 'de', 'encontrar', 'e', 'abrir', 'uma', 'caixa', 'contendo', 'um', 'feitiço', 'amaldiçoado', 'semelhante', 'a', 'um', 'dedo', 'podre', ',', 'sua', 'escola', 'é', 'atacada', 'por', 'criaturas', 'fantasmas', 'conhecidas', 'como', 'Maldições', '.', 'Para', 'proteger', 'seus', 'amigos', ',', 'ele', 'consome', 'o', 'dedo', 'podre', 'e', 'fica', 'possuído', 'por', 'uma', 'maldição', 'conhecida', 'como', 'Ryoumen', 'Sukuna', '.']
# Stop Word:  [True, False, True, False, False, True, True, False, True, False, False, True, True, False, True, False, True, False, True, False, False, True, True, False, True, False, True, False, False, True, False, False, False, True, True, False, False, False, True, False, True, False, True, False, False, False, True, False, False, True, False, True, False, False, True, False, True, False, False, True, False, False, True, True, False, True, True, False, False, False]
# Alfanumérico:  [True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False]
# Maiúsculo:  [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Pontuação:  [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True]
# Número:  [True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Sentença Inicial:  [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]

# %%
print("Tokens: ", [token.text for token in documento])
print("Formato: ", [token.shape_ for token in documento])
# Out:
# Tokens:  ['Um', 'atleta', 'de', '15', 'anos', 'que', 'se', 'junta', 'ao', 'Clube', 'Oculto', 'de', 'sua', 'escola', 'para', 'evitar', 'o', 'time', 'de', 'atletismo', '.', 'Depois', 'de', 'encontrar', 'e', 'abrir', 'uma', 'caixa', 'contendo', 'um', 'feitiço', 'amaldiçoado', 'semelhante', 'a', 'um', 'dedo', 'podre', ',', 'sua', 'escola', 'é', 'atacada', 'por', 'criaturas', 'fantasmas', 'conhecidas', 'como', 'Maldições', '.', 'Para', 'proteger', 'seus', 'amigos', ',', 'ele', 'consome', 'o', 'dedo', 'podre', 'e', 'fica', 'possuído', 'por', 'uma', 'maldição', 'conhecida', 'como', 'Ryoumen', 'Sukuna', '.']
# Formato:  ['Xx', 'xxxx', 'xx', 'dd', 'xxxx', 'xxx', 'xx', 'xxxx', 'xx', 'Xxxxx', 'Xxxxx', 'xx', 'xxx', 'xxxx', 'xxxx', 'xxxx', 'x', 'xxxx', 'xx', 'xxxx', '.', 'Xxxxx', 'xx', 'xxxx', 'x', 'xxxx', 'xxx', 'xxxx', 'xxxx', 'xx', 'xxxx', 'xxxx', 'xxxx', 'x', 'xx', 'xxxx', 'xxxx', ',', 'xxx', 'xxxx', 'x', 'xxxx', 'xxx', 'xxxx', 'xxxx', 'xxxx', 'xxxx', 'Xxxxx', '.', 'Xxxx', 'xxxx', 'xxxx', 'xxxx', ',', 'xxx', 'xxxx', 'x', 'xxxx', 'xxxx', 'x', 'xxxx', 'xxxx', 'xxx', 'xxx', 'xxxx', 'xxxx', 'xxxx', 'Xxxxx', 'Xxxxx', '.']

# %%
for token in documento:
  if token.like_num:
    print("Número encontrado: ", token.text)
  if token.is_punct:
    print("Pontuação encontrada: ", token.text)
# Out:
# Número encontrado:  Um
# Número encontrado:  15
# Pontuação encontrada:  .
# Número encontrado:  um
# Número encontrado:  um
# Pontuação encontrada:  ,
# Pontuação encontrada:  .
# Pontuação encontrada:  ,
# Pontuação encontrada:  .

# %% [markdown]
# ##Pós-Taggin e Dependências

# %%
for token in documento:
  print(token.text, " - ", token.pos_, " - ", token.dep_, " - ", token.lemma_, " - ", token.shape_)
# Out:
# Um  -  DET  -  det  -  Um  -  Xx
# atleta  -  NOUN  -  ROOT  -  atleta  -  xxxx
# de  -  ADP  -  case  -  de  -  xx
# 15  -  NUM  -  nummod  -  15  -  dd
# anos  -  NOUN  -  nmod  -  ano  -  xxxx
# que  -  PRON  -  nsubj  -  que  -  xxx
# se  -  PRON  -  expl  -  se  -  xx
# junta  -  VERB  -  acl:relcl  -  junto  -  xxxx
# ao  -  ADP  -  case  -  ao  -  xx
# Clube  -  PROPN  -  obl  -  Clube  -  Xxxxx
# Oculto  -  PROPN  -  flat:name  -  Oculto  -  Xxxxx
# de  -  ADP  -  case  -  de  -  xx
# sua  -  DET  -  det  -  suar  -  xxx
# escola  -  NOUN  -  nmod  -  escola  -  xxxx
# para  -  SCONJ  -  mark  -  parir  -  xxxx
# evitar  -  VERB  -  advcl  -  evitar  -  xxxx
# o  -  DET  -  det  -  o  -  x
# time  -  NOUN  -  obj  -  time  -  xxxx
# de  -  ADP  -  case  -  de  -  xx
# atletismo  -  NOUN  -  nmod  -  atletismo  -  xxxx
# .  -  PUNCT  -  punct  -  .  -  .
# Depois  -  ADV  -  mark  -  Depois  -  Xxxxx
# de  -  ADP  -  fixed  -  de  -  xx
# encontrar  -  VERB  -  advcl  -  encontrar  -  xxxx
# e  -  CCONJ  -  cc  -  e  -  x
# abrir  -  VERB  -  conj  -  abrir  -  xxxx
# uma  -  DET  -  det  -  umar  -  xxx
# caixa  -  NOUN  -  obj  -  caixa  -  xxxx
# contendo  -  VERB  -  acl  -  conter  -  xxxx
# um  -  DET  -  det  -  um  -  xx
# feitiço  -  NOUN  -  obj  -  feitiço  -  xxxx
# amaldiçoado  -  VERB  -  acl  -  amaldiçoar  -  xxxx
# semelhante  -  ADJ  -  xcomp  -  semelhante  -  xxxx
# a  -  ADP  -  case  -  o  -  x
# um  -  DET  -  det  -  um  -  xx
# dedo  -  NOUN  -  obl  -  dedo  -  xxxx
# podre  -  ADJ  -  amod  -  podre  -  xxxx
# ,  -  PUNCT  -  punct  -  ,  -  ,
# sua  -  DET  -  det  -  suar  -  xxx
# escola  -  NOUN  -  nsubj:pass  -  escola  -  xxxx
# é  -  AUX  -  aux:pass  -  ser  -  x
# atacada  -  VERB  -  ROOT  -  atacar  -  xxxx
# por  -  ADP  -  case  -  por  -  xxx
# criaturas  -  NOUN  -  obl:agent  -  criatura  -  xxxx
# fantasmas  -  ADJ  -  amod  -  fantasma  -  xxxx
# conhecidas  -  VERB  -  acl  -  conhecido  -  xxxx
# como  -  ADP  -  case  -  comer  -  xxxx
# Maldições  -  NOUN  -  xcomp  -  Maldições  -  Xxxxx
# .  -  PUNCT  -  punct  -  .  -  .
# Para  -  SCONJ  -  mark  -  Para  -  Xxxx
# proteger  -  VERB  -  advcl  -  proteger  -  xxxx
# seus  -  DET  -  det  -  seu  -  xxxx
# amigos  -  NOUN  -  obj  -  amigo  -  xxxx
# ,  -  PUNCT  -  punct  -  ,  -  ,
# ele  -  PRON  -  nsubj  -  ele  -  xxx
# consome  -  VERB  -  ROOT  -  consumir  -  xxxx
# o  -  DET  -  det  -  o  -  x
# dedo  -  NOUN  -  obj  -  dedo  -  xxxx
# podre  -  ADJ  -  amod  -  podre  -  xxxx
# e  -  CCONJ  -  cc  -  e  -  x
# fica  -  VERB  -  conj  -  ficar  -  xxxx
# possuído  -  VERB  -  xcomp  -  possuir  -  xxxx
# por  -  ADP  -  case  -  por  -  xxx
# uma  -  DET  -  det  -  umar  -  xxx
# maldição  -  NOUN  -  obl:agent  -  maldição  -  xxxx
# conhecida  -  VERB  -  acl  -  conhecido  -  xxxx
# como  -  ADP  -  case  -  comer  -  xxxx
# Ryoumen  -  PROPN  -  xcomp  -  Ryoumen  -  Xxxxx
# Sukuna  -  PROPN  -  flat:name  -  Sukuna  -  Xxxxx
# .  -  PUNCT  -  punct  -  .  -  .

# %%
#morfologia

for token in documento:
  print(token.text, " - ", token.morph)
# Out:
# Um  -  Definite=Ind|Gender=Masc|Number=Sing|PronType=Art
# atleta  -  Gender=Masc|Number=Sing
# de  -
# 15  -  NumType=Card
# anos  -  Gender=Masc|Number=Plur
# que  -  Gender=Masc|Number=Plur|PronType=Rel
# se  -  Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# junta  -  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# ao  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# Clube  -  Gender=Masc|Number=Sing
# Oculto  -  Number=Sing
# de  -
# sua  -  Gender=Fem|Number=Sing|PronType=Prs
# escola  -  Gender=Fem|Number=Sing
# para  -
# evitar  -  VerbForm=Inf
# o  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# time  -  Gender=Masc|Number=Sing
# de  -
# atletismo  -  Gender=Masc|Number=Sing
# .  -
# Depois  -
# de  -
# encontrar  -  VerbForm=Inf
# e  -
# abrir  -  VerbForm=Inf
# uma  -  Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# caixa  -  Gender=Fem|Number=Sing
# contendo  -  VerbForm=Ger
# um  -  Definite=Ind|Gender=Masc|Number=Sing|PronType=Art
# feitiço  -  Gender=Masc|Number=Sing
# amaldiçoado  -  Gender=Masc|Number=Sing|VerbForm=Part
# semelhante  -  Gender=Masc|Number=Sing
# a  -
# um  -  Definite=Ind|Gender=Masc|Number=Sing|PronType=Art
# dedo  -  Gender=Masc|Number=Sing
# podre  -  Gender=Masc|Number=Sing
# ,  -
# sua  -  Gender=Fem|Number=Sing|PronType=Prs
# escola  -  Gender=Fem|Number=Sing
# é  -  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# atacada  -  Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass
# por  -
# criaturas  -  Gender=Fem|Number=Plur
# fantasmas  -  Gender=Fem|Number=Plur
# conhecidas  -  Gender=Fem|Number=Plur|VerbForm=Part
# como  -
# Maldições  -  Gender=Fem|Number=Plur
# .  -
# Para  -
# proteger  -  VerbForm=Inf
# seus  -  Gender=Masc|Number=Plur|PronType=Prs
# amigos  -  Gender=Masc|Number=Plur
# ,  -
# ele  -  Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# consome  -  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# o  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# dedo  -  Gender=Masc|Number=Sing
# podre  -  Gender=Masc|Number=Sing
# e  -
# fica  -  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# possuído  -  Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass
# por  -
# uma  -  Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# maldição  -  Gender=Fem|Number=Sing
# conhecida  -  Gender=Fem|Number=Sing|VerbForm=Part
# como  -
# Ryoumen  -  Gender=Masc|Number=Sing
# Sukuna  -  Number=Sing
# .  -

# %%
#tag

for token in documento:
  print(token.text, " - ", token.tag_)
# Out:
# Um  -  DET
# atleta  -  NOUN
# de  -  ADP
# 15  -  NUM
# anos  -  NOUN
# que  -  PRON
# se  -  PRON
# junta  -  VERB
# ao  -  ADP
# Clube  -  PROPN
# Oculto  -  PROPN
# de  -  ADP
# sua  -  DET
# escola  -  NOUN
# para  -  SCONJ
# evitar  -  VERB
# o  -  DET
# time  -  NOUN
# de  -  ADP
# atletismo  -  NOUN
# .  -  PUNCT
# Depois  -  ADV
# de  -  ADP
# encontrar  -  VERB
# e  -  CCONJ
# abrir  -  VERB
# uma  -  DET
# caixa  -  NOUN
# contendo  -  VERB
# um  -  DET
# feitiço  -  NOUN
# amaldiçoado  -  VERB
# semelhante  -  ADJ
# a  -  ADP
# um  -  DET
# dedo  -  NOUN
# podre  -  ADJ
# ,  -  PUNCT
# sua  -  DET
# escola  -  NOUN
# é  -  AUX
# atacada  -  VERB
# por  -  ADP
# criaturas  -  NOUN
# fantasmas  -  ADJ
# conhecidas  -  VERB
# como  -  ADP
# Maldições  -  NOUN
# .  -  PUNCT
# Para  -  SCONJ
# proteger  -  VERB
# seus  -  DET
# amigos  -  NOUN
# ,  -  PUNCT
# ele  -  PRON
# consome  -  VERB
# o  -  DET
# dedo  -  NOUN
# podre  -  ADJ
# e  -  CCONJ
# fica  -  VERB
# possuído  -  VERB
# por  -  ADP
# uma  -  DET
# maldição  -  NOUN
# conhecida  -  VERB
# como  -  ADP
# Ryoumen  -  PROPN
# Sukuna  -  PROPN
# .  -  PUNCT

# %% [markdown]
# ##Listando Entidades Nomeadas

# %%
for ent in documento.ents:
  print(ent.text, " - ", ent.label_)
# Out:
# Clube Oculto  -  MISC
# Maldições  -  MISC
# Ryoumen Sukuna  -  MISC

# %% [markdown]
# ##Gerenciando Stop Words

# %%
for token in documento:
  if token.is_stop:
    print("Stop Word: ", token.text)
# Out:
# Stop Word:  Um
# Stop Word:  de
# Stop Word:  que
# Stop Word:  se
# Stop Word:  ao
# Stop Word:  de
# Stop Word:  sua
# Stop Word:  para
# Stop Word:  o
# Stop Word:  de
# Stop Word:  Depois
# Stop Word:  de
# Stop Word:  e
# Stop Word:  uma
# Stop Word:  um
# Stop Word:  a
# Stop Word:  um
# Stop Word:  sua
# Stop Word:  é
# Stop Word:  por
# Stop Word:  como
# Stop Word:  Para
# Stop Word:  seus
# Stop Word:  ele
# Stop Word:  o
# Stop Word:  e
# Stop Word:  por
# Stop Word:  uma
# Stop Word:  conhecida
# Stop Word:  como

# %%
for words in nlp.Defaults.stop_words:
  print(words)
# Out:
# lá
# iniciar
# parece
# sob
# já
# tentaram
# usar
# embora
# no
# primeiro
# ambas
# tem
# estão
# todas
# temos
# ora
# umas
# que
# atrás
# à
# quinta
# vezes
# tudo
# eu
# estar
# tarde
# deverá
# nos
# meus
# têm
# algumas
# além
# sou
# lado
# qual
# ele
# tentei
# suas
# contra
# certeza
# vossos
# entre
# fazemos
# grupo
# dois
# fazia
# tempo
# sexta
# em
# seis
# vossas
# quê
# ver
# maior
# fez
# tu
# num
# quieto
# me
# onze
# caminho
# a
# nesse
# era
# tenho
# forma
# partir
# posso
# só
# fazeis
# nenhuma
# inicio
# qualquer
# dar
# aqueles
# conhecida
# vinda
# vossa
# esse
# como
# alguns
# devem
# minhas
# outra
# o
# deste
# ponto
# dentro
# local
# todo
# usa
# favor
# novas
# vocês
# vais
# foi
# tive
# estará
# os
# teu
# bom
# ser
# meses
# sete
# elas
# estivemos
# menos
# aos
# adeus
# breve
# pegar
# por
# des
# números
# cujo
# nunca
# questão
# cima
# estivestes
# nas
# estado
# tente
# logo
# seu
# dão
# as
# novo
# são
# você
# acerca
# essas
# então
# possivelmente
# tanta
# uns
# saber
# comprido
# quinto
# ir
# assim
# longe
# vos
# ela
# este
# dez
# podia
# pelas
# das
# mal
# comprida
# dá
# meu
# sexto
# onde
# é
# tiveste
# sétima
# nova
# mil
# vão
# foram
# agora
# estive
# nessa
# coisa
# uma
# até
# meio
# porquê
# não
# boa
# pode
# novos
# daquela
# faz
# tanto
# um
# estava
# tivestes
# algo
# nossas
# dos
# talvez
# mais
# apenas
# muito
# sistema
# se
# fora
# final
# vez
# aquele
# custa
# oitavo
# fazes
# nuns
# mesmo
# tiveram
# tentar
# e
# nesta
# seria
# também
# tens
# dezanove
# eles
# fui
# lugar
# oito
# sempre
# geral
# vinte
# ou
# somente
# quero
# com
# está
# do
# vosso
# cada
# vários
# quando
# dezoito
# grandes
# nove
# irá
# às
# naquele
# debaixo
# foste
# obrigado
# segundo
# grande
# desta
# isso
# minha
# portanto
# treze
# porque
# ainda
# esses
# número
# cinco
# obrigada
# fará
# tipo
# através
# pôde
# nossa
# esta
# outras
# quieta
# maiorias
# possível
# nossos
# bastante
# oitava
# vós
# sem
# poderá
# pelo
# põe
# vindo
# ambos
# tal
# exemplo
# apontar
# doze
# cedo
# daquele
# deve
# zero
# és
# muitos
# tivemos
# quatro
# põem
# primeira
# dezassete
# baixo
# quarto
# pois
# último
# cá
# da
# teus
# próprio
# aí
# for
# enquanto
# área
# falta
# tuas
# corrente
# essa
# próximo
# apoia
# inclusive
# lhe
# povo
# certamente
# te
# eventual
# dizem
# dessa
# mas
# nós
# estas
# na
# outros
# fim
# perto
# tão
# conhecido
# podem
# vêm
# numa
# aquilo
# ali
# estiveram
# sim
# neste
# disso
# vens
# pouco
# teve
# isto
# nosso
# sois
# segunda
# momento
# bem
# ter
# vai
# todos
# diz
# aquela
# sétimo
# relação
# porém
# somos
# pelos
# pela
# de
# parte
# direita
# estou
# ligado
# estiveste
# esteve
# mês
# quais
# estás
# antes
# aquelas
# diante
# quem
# quer
# estes
# nem
# fazer
# maioria
# fomos
# porquanto
# apoio
# faço
# quanto
# sobre
# sua
# pontos
# valor
# próxima
# aqui
# três
# demais
# pouca
# sabe
# posição
# fostes
# querem
# terceira
# tua
# nada
# ademais
# naquela
# quinze
# vem
# cuja
# quarta
# conselho
# sei
# terceiro
# tais
# cento
# veja
# duas
# fazem
# para
# desse
# depois
# catorze
# ontem
# dezasseis
# seus
# menor
# tendes
# toda
# após
# nível
# contudo
# poder
# desde
# ao
# máximo
# puderam
# dizer

# %%
#adicionar nova stop word

nlp.Defaults.stop_words.add("eita")
nlp.vocab['eita'].is_stop = True

# %%
# verificando

nlp.vocab['eita'].is_stop
# Out:
# True

# %%
#remoção de stop words
token_lista = []
for token in documento:
  token_lista.append(token.text)


stop_lista =[]
for words in nlp.Defaults.stop_words:
  stop_lista.append(words)

#esse for gera um laço com as palavras que estão na lista de token mas não estão na lista de stop words
semstop = [word for word in token_lista if not word in stop_lista]

print(documento.text)
print(semstop)
# Out:
# Um atleta de 15 anos que se junta ao Clube Oculto de sua escola para evitar o time de atletismo. Depois de encontrar e abrir uma caixa contendo um feitiço amaldiçoado semelhante a um dedo podre, sua escola é atacada por criaturas fantasmas conhecidas como Maldições. Para proteger seus amigos, ele consome o dedo podre e fica possuído por uma maldição conhecida como Ryoumen Sukuna.
# ['Um', 'atleta', '15', 'anos', 'junta', 'Clube', 'Oculto', 'escola', 'evitar', 'time', 'atletismo', '.', 'Depois', 'encontrar', 'abrir', 'caixa', 'contendo', 'feitiço', 'amaldiçoado', 'semelhante', 'dedo', 'podre', ',', 'escola', 'atacada', 'criaturas', 'fantasmas', 'conhecidas', 'Maldições', '.', 'Para', 'proteger', 'amigos', ',', 'consome', 'dedo', 'podre', 'fica', 'possuído', 'maldição', 'Ryoumen', 'Sukuna', '.']

# %% [markdown]
# ##Vocabulário

# %%
print("Hash: ", nlp.vocab.strings["dados"])
print("Hash: ", documento.vocab.strings["dados"])
print("String: ", nlp.vocab.strings[6013848609874238634])
# Out:
# Hash:  6013848609874238634
# Hash:  6013848609874238634
# String:  dados

# %%
lex = nlp.vocab["dados"]
print(lex.text, " - ", lex.orth, " - ", lex.is_alpha, " - ", lex.is_lower)
# Out:
# dados  -  6013848609874238634  -  True  -  True

# %%
#print(nlp("dados").vector.shape)
#print(nlp("dados").vector)
print(nlp("dados são uma nova forma de ver o mundo").vector)
# Out:
# [ 0.5255733  -1.0520301  -1.0489888   0.22808893 -2.7599888   0.91837215
#  -1.6993556  -0.44524103 -2.209261   -1.2901455   0.9939946  -1.3996754
#   0.7378708  -1.6957022  -1.382649   -1.1241877   2.503239    1.3766589
#  -0.63682556  2.7080245  -0.6679023   0.7990059  -1.3761922   1.6491444
#  -0.6950322   0.69378555 -0.19840002  1.6926199  -0.3071023   0.71506053
#   0.03211441  0.27212894 -1.9055911  -1.5586021  -0.9775556   0.7999823
#  -0.9553054   0.5265729  -0.87427455 -1.2073755  -2.117481    1.2241988
#   1.5149522  -0.79308677 -1.1521667   0.13741441 -1.7882053   0.50415283
#   1.3089666   0.06542712 -0.6260744  -1.5624356  -0.707184   -1.2425367
#  -0.04237115 -0.5879791   1.7004043  -0.24798778  0.11633212 -0.55506223
#   2.0148706   0.01965364  0.92778563  2.3571968  -0.49526003  1.0151839
#   0.57112557  1.3510779  -0.3038622  -0.24523441 -0.42284998 -0.69732666
#   0.71998227  0.2875956   0.10309222 -0.6866155   2.128672    0.9791889
#  -1.4044011  -0.4600078   0.10599887  0.84635675  1.2420444   0.40497887
#   0.24567226 -2.4633954   0.30174115 -1.2952554   0.5795323  -1.899822
#  -0.74619776  2.998889    2.0798278  -0.9101444   0.27261782  0.3154811
#   3.1923532   1.315211   -3.1751957   0.03176559  1.1431444   1.6177245
#  -1.0905743   0.6142689   1.0441045  -1.0070856  -0.6415578  -0.75415665
#   0.04653723 -0.7180089  -0.09737895  0.02209669 -0.43218002 -0.37869656
#  -1.4787056  -0.8019056   2.2888644  -0.58004665 -0.35054     0.8161524
#   0.56656885 -3.1986172  -0.13080996 -0.87027764  0.19671117 -0.18788989
#   2.1433      0.5740978   0.79283893  1.1020746   0.06806201  0.14578162
#  -0.48713335 -0.9247377   0.84602445  1.326062   -0.13929449 -2.2536204
#   0.8378011   1.8202833  -2.1101756   0.01467665 -0.1241987  -0.28894553
#  -2.689321    0.35465997  1.3067889   0.78942555 -3.1275606  -0.70258003
#   1.1796956  -0.09419552 -0.39751524 -2.17274     0.00593225  0.11152443
#  -0.40126875 -0.7324776  -1.110687   -1.6154889   1.9177108   0.59479684
#  -0.9205568   1.6399556   2.1313922   0.8705971  -0.4869177  -2.5268655
#  -0.20582779 -1.351448    1.0684322   1.0798033   0.7770678  -0.88195336
#  -0.94633335 -1.6027511   2.097808   -0.44511667 -1.657932    1.3012689
#   1.4642056   0.07117888 -0.45494658  1.4971966   1.3140267  -0.48212782
#   1.0694442  -2.269592    1.3391188   1.5931556  -1.7781789  -1.465089
#   0.23485115 -2.34892     0.940096    0.5333122  -0.74473196 -1.2676699
#  -0.40783006 -0.7384778  -2.09579     2.0488043  -1.182571    0.37707764
#   1.1301712   0.28928337  1.3739567  -1.0200423   1.2103223   0.04722336
#   1.3624822  -1.2681168   1.4688356   0.8132446  -1.719049    1.8276443
#   1.0804734  -0.31434     0.88836336 -0.67704093 -1.0336466  -0.9087268
#   0.09643783 -2.5777566  -0.08628993 -0.8835056  -0.5007     -2.010551
#   0.9359345  -1.839522   -0.45124334 -1.67075     0.1972278  -0.69528896
#  -0.8587457  -0.25463215  0.23403136 -1.7613523   0.39325333  2.0033166
#   0.16394782 -0.5912411   0.4513964   0.38095444  0.9961722  -0.5356072
#  -0.24399893  1.2084801   1.047721   -0.3533555  -0.68883884 -0.05879111
#  -1.0547067  -0.9298345   0.1543278   0.22240782 -0.8161553   2.490319
#  -1.5402923   0.59167856 -1.8444476   0.68242     2.5562222   0.99307674
#   0.02924996 -0.70853776 -1.0495977   0.13625993  2.1210868   1.4868933
#   3.163472   -0.43712902 -0.514627    2.9385633  -2.2680051   0.10609888
#   2.2179537   0.63511777  0.40360793 -1.1280782  -1.7189742  -0.46922117
#   2.9208887  -0.7004363  -0.36562064  1.1512333  -1.4175044  -0.44106555
#  -0.48883343 -0.5042111   0.28768444  3.4773679  -1.2891389  -0.65457785
#   0.3968733  -1.9304742   2.1593056  -0.50640225 -1.4050981   1.26994   ]

# %% [markdown]
# ##Buscando Similaridade

# %%
documento1 = nlp("Ele viaja regularmente de carro")
documento2 = nlp("Ela viaja regularmente de avião")

print(documento1.similarity(documento2))
print(documento2.similarity(documento1))
# Out:
# 0.894174124950273
# 0.894174124950273

# %%
documento3 = nlp("Devemos dizer comprimento ou cumprimento?")
tokenA = documento3[2]
print(tokenA)
tokenB = documento3[4]
print(tokenB)

print(tokenA.similarity(tokenB))
# Out:
# comprimento
# cumprimento
# 0.580434

# %%
documento4 = nlp("Ele pede descrição. Ele pede discrição")
partA = documento4[0:3]
print(partA)
partB = documento3[4:7]
print(partB)

print(partA.similarity(partB))
# Out:
# Ele pede descrição
# cumprimento?
# 0.0978557

# %% [markdown]
# ##Busca de Expressões com Matching

# %%
from spacy.matcher import Matcher

# %%
#identificando um padrao
documento5 = nlp("Você pode ligar para (51) - 996465670 ou (11) 123456789")

matcher = Matcher(nlp.vocab)
padrao = [{"ORTH": "("}, {"SHAPE": "dd"}, {"ORTH": ")"}, {"ORTH": "-", "OP": "?"}, {"IS_DIGIT": True}]
matcher.add("telefone", [padrao])
matches = matcher(documento5)
for id, inicio, fim in matches:
  print(documento5[inicio:fim])
# Out:
# (51) - 996465670
# (11) 123456789

# %%
#identificando palavras escritas de forma diferente

documento6 = nlp("Estamos infectados com micro organismos. MICROORGANISMOS são perigosos. Não enxergamos micro-organismos")
matcher = Matcher(nlp.vocab)
padrao1 = [{"LOWER": "micro-organismos"}]
padrao2 = [{"LOWER": "microorganismos"}]
padrao3 = [{"LOWER": "micro"}, {"LOWER": "organismos"}]

matcher.add("padrao", [padrao1, padrao2, padrao3])

matches = matcher(documento6)
for id, inicio, fim in matches:
  print(documento6[inicio:fim])
# Out:
# micro organismos
# MICROORGANISMOS
# micro-organismos

# %% [markdown]
# ##Visualização com Displacy
#
# Existem dois estilos principais:
# * Entidades nomeadas
# * Dependencia
#
# É personalizável, pois é possível modificar cor, fundo, fonte, distância, etc.

# %%
from spacy import displacy

#visualização de entidades
documento = nlp("O Studio Ghibli, fundado por Hayao Miyazaki e Isao Takahata em 1985, é um dos estúdios de animação mais icônicos do mundo. Com filmes aclamados como Meu Vizinho Totoro, A Viagem de Chihiro e Princesa Mononoke, o estúdio conquistou uma base de fãs global apaixonada e dedicada.")
displacy.render(documento, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">O
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Studio Ghibli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , fundado por
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hayao Miyazaki
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  e
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Isao Takahata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  em 1985, é um dos estúdios de animação mais icônicos do mundo. Com filmes aclamados como
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meu Vizinho Totoro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A Viagem de Chihiro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Princesa Mononoke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , o estúdio conquistou uma base de fãs global apaixonada e dedicada.</div></span>

# %%
#visualização de dependencia
displacy.render(documento, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="873bf36303944f448094dfdb15e0cc0c-0" class="displacy" width="8275" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Studio</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Ghibli,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">fundado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Hayao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Miyazaki</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Isao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Takahata</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">1985,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">é</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">um</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">dos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">estúdios</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">animação</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">mais</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">icônicos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">mundo.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Com</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">filmes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">aclamados</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">como</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Meu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Vizinho</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">Totoro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Viagem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor

# %%
displacy.render(documento, style="dep", jupyter=True,
                options={'compact': True, 'distance':100, 'color': '#493082', 'bg': '#56D8FD', 'font': 'Arial'})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="c59c4d3af6944938a9bb746fb3423e02-0" class="displacy" width="4750" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #493082; background: #56D8FD; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">O</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Studio</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Ghibli,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">fundado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">Hayao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Miyazaki</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Isao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Takahata</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">1985,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">é</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">um</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">dos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">estúdios</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">animação</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">mais</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">icônicos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">mundo.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">Com</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">filmes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">aclamados</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">como</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">Meu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Vizinho</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Totoro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Viagem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="305

# %% [markdown]
# ##Gerenciando Pipelines

# %%
print("Pipeline Normal: ", nlp.pipe_names)
# Out:
# Pipeline Normal:  ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#removendo etapa

nlp.remove_pipe('tok2vec')
print("Pipeline sem tok2vec: ", nlp.pipe_names)
# Out:
# Pipeline sem tok2vec:  ['morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#adicionando etapa e escolhendo onde adicionar

nlp.add_pipe('tok2vec', after='morphologizer')
print("Pipeline: ", nlp.pipe_names)
# Out:
# Pipeline:  ['morphologizer', 'tok2vec', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
